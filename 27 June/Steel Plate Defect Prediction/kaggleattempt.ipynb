# %%
import statsmodels.api as sm
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import numpy as np 
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,AdaBoostClassifier,VotingClassifier,HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score,r2_score,recall_score,roc_auc_score,confusion_matrix,classification_report
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import lightgbm as lgb
import warnings
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.exceptions import DataConversionWarning
from catboost import CatBoostClassifier,Pool
from catboost.utils import eval_metric
warnings.filterwarnings("ignore", category=DataConversionWarning)
warnings.filterwarnings("ignore")
from IPython.display import display, HTML
from sklearn.metrics import auc
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import cross_val_score
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
from scipy.stats import ttest_ind,chi2_contingency
from sklearn.naive_bayes import GaussianNB
from sklearn.utils import class_weight

import pandas as pd 
from sklearn.preprocessing import PowerTransformer, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from scipy.stats import skew
from sklearn.model_selection import train_test_split
import seaborn as sns
from matplotlib import pyplot as plt
import os

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %% [markdown]
# ### Feature Engineering

# %%
train['X_Area_Diff'] = train['X_Maximum'] - train['X_Minimum']
train['Perimeter_Ratio'] = train['X_Perimeter'] / train['Y_Perimeter']
train['Is_Steel_A300'] = train['TypeOfSteel_A300'].apply(lambda x: 1 if x == 1 else 0)
train['Combined_Edges_Index'] = train['Edges_Index'] + train['Edges_X_Index'] + train['Edges_Y_Index']

# %%
test['X_Area_Diff'] = test['X_Maximum'] - test['X_Minimum']
test['Perimeter_Ratio'] = test['X_Perimeter'] / test['Y_Perimeter']
test['Is_Steel_A300'] = test['TypeOfSteel_A300'].apply(lambda x: 1 if x == 1 else 0)
test['Combined_Edges_Index'] = test['Edges_Index'] + test['Edges_X_Index'] + test['Edges_Y_Index']

# %% [markdown]
# ### Column Transformer

# %%
unique_counts = train.nunique()
#Threshold to distinguish continous and categorical
threshold = 12
continuous_vars_temp = unique_counts[unique_counts > threshold].index.tolist()
#categorical_vars = unique_counts[unique_counts <= threshold].index.tolist()
if 'id' in continuous_vars_temp:
    continuous_vars_temp.remove('id')

# %%
skew_threshold = 0.5  
# Define the columns for transformation
columns_to_transform = ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas',
                        'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity', 'Minimum_of_Luminosity',
                        'Maximum_of_Luminosity', 'Length_of_Conveyer', 'Steel_Plate_Thickness',
                        'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index',
                        'Edges_X_Index', 'Edges_Y_Index', 'LogOfAreas', 'Log_X_Index',
                        'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index', 'SigmoidOfAreas',
                        'X_Area_Diff', 'Perimeter_Ratio', 'Combined_Edges_Index']

# Calculate skewness for each column
skewness = train[columns_to_transform].apply(lambda x: x.skew())
power_transformer = PowerTransformer(method='yeo-johnson', standardize=True)
function_transformer = FunctionTransformer(np.log1p, validate=True)  
transformer = ColumnTransformer([
    ('power_transform', power_transformer, skewness[skewness > skew_threshold].index),
    ('log_transform', function_transformer, skewness[skewness <= skew_threshold].index)
])

train[columns_to_transform] = transformer.fit_transform(train[columns_to_transform])

# %%
unique_counts = test.nunique()
#Threshold to distinguish continous and categorical
threshold = 12
continuous_vars_test = unique_counts[unique_counts > threshold].index.tolist()
#categorical_vars = unique_counts[unique_counts <= threshold].index.tolist()
if 'id' in continuous_vars_test:
    continuous_vars_test.remove('id')

# %%
skew_threshold = 0.5  
# Define the columns for transformation
columns_to_transform = ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas',
                        'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity', 'Minimum_of_Luminosity',
                        'Maximum_of_Luminosity', 'Length_of_Conveyer', 'Steel_Plate_Thickness',
                        'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index',
                        'Edges_X_Index', 'Edges_Y_Index', 'LogOfAreas', 'Log_X_Index',
                        'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index', 'SigmoidOfAreas',
                        'X_Area_Diff', 'Perimeter_Ratio', 'Combined_Edges_Index']

# Calculate skewness for each column
skewness = test[columns_to_transform].apply(lambda x: x.skew())
power_transformer = PowerTransformer(method='yeo-johnson', standardize=True)
function_transformer = FunctionTransformer(np.log1p, validate=True)  
transformer = ColumnTransformer([
    ('power_transform', power_transformer, skewness[skewness > skew_threshold].index),
    ('log_transform', function_transformer, skewness[skewness <= skew_threshold].index)
])

test[columns_to_transform] = transformer.fit_transform(test[columns_to_transform])

# %%
numerical_columns = train.select_dtypes(include='number').columns

# %% [markdown]
# ### Remove Outliers

# %%
def remove_outliers_replace(data, columns, threshold=1.5):
    data_no_outliers = data.copy()

    for column in columns:
        Q1 = data_no_outliers[column].quantile(0.25)
        Q3 = data_no_outliers[column].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - threshold * IQR
        upper_bound = Q3 + threshold * IQR

        is_outlier = (data_no_outliers[column] < lower_bound) | (data_no_outliers[column] > upper_bound)

        if data_no_outliers[column].dtype == 'O':  # Categorical column
            median_value = data_no_outliers.loc[~is_outlier, column].mode().iloc[0]
            data_no_outliers.loc[is_outlier, column] = median_value
        else:  # Numerical column
            mean_value = data_no_outliers.loc[~is_outlier, column].mean()
            data_no_outliers.loc[is_outlier, column] = mean_value

    return data_no_outliers

columns_to_remove_outliers_replace = continuous_vars_temp
train = remove_outliers_replace(train, columns_to_remove_outliers_replace)
test = remove_outliers_replace(test, columns_to_remove_outliers_replace)

# %%
train.drop(columns='id',axis = 1,inplace = True)

# %%
X = train.drop(['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults'], axis=1)
y = train[['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']]

# %% [markdown]
# ### Hypothesis Testing

# %%
import pandas as pd
from scipy.stats import ttest_ind

target_columns = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']

# Perform pairwise t-tests for each target column with all other columns
p_values = {}
for target in target_columns:
    p_values[target] = {}  # Initialize a dictionary for storing p-values for this target
    for column in train.columns:
        if column != target:  # Exclude the target column itself
            t_stat, p_value = ttest_ind(train[target], train[column])
            p_values[target][column] = p_value

# Convert the nested dictionary to a DataFrame for better visualization
p_values_df = pd.DataFrame(p_values)

# %%
target_columns = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']

# Perform pairwise t-tests for each target column with all other columns
significant_columns = {}
for target in target_columns:
    p_values = {}  # Initialize a dictionary for storing p-values for this target
    for column in train.columns:
        if column != target:  # Exclude the target column itself
            t_stat, p_value = ttest_ind(train[target], train[column])
            p_values[column] = p_value
    
    # Filter columns based on p-value threshold (e.g., 0.05)
    significant_columns[target] = [col for col, p_val in p_values.items() if p_val <= 0.05]

# Display the number of significant columns for each target column
for target, cols in significant_columns.items():
    print(f"Number of significant columns for '{target}': {len(cols)}")
# Out:
# Number of significant columns for 'Pastry': 37
# Number of significant columns for 'Z_Scratch': 36
# Number of significant columns for 'K_Scatch': 37
# Number of significant columns for 'Stains': 34
# Number of significant columns for 'Dirtiness': 34
# Number of significant columns for 'Bumps': 37
# Number of significant columns for 'Other_Faults': 36

# %%
test.drop(columns=['id'], inplace=True)

# %%
train = X
target = y

# %%
test.shape, train.shape, target.shape
# Out:
# ((12814, 31), (19219, 31), (19219, 7))

# %%
train.shape
# Out:
# (19219, 31)

# %% [markdown]
# ## Predict 7 columns with one model

# %%
from pycaret.classification import *

# %%
for i in target.columns:
    print(target[i].value_counts())
# Out:
# 0    17753
# 1     1466
# Name: Pastry, dtype: int64
# 0    18069
# 1     1150
# Name: Z_Scratch, dtype: int64
# 0    15787
# 1     3432
# Name: K_Scatch, dtype: int64
# 0    18651
# 1      568
# Name: Stains, dtype: int64
# 0    18734
# 1      485
# Name: Dirtiness, dtype: int64
# 0    14456
# 1     4763
# Name: Bumps, dtype: int64
# 0    12661
# 1     6558
# Name: Other_Faults, dtype: int64

# %%
_ = setup(data=train, target=target[['Pastry','Z_Scratch','K_Scatch','Stains','Dirtiness','Bumps','Other_Faults']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 _ = setup(data=train, target=target[['Pastry','Z_Scratch','K_Scatch','Stains','Dirtiness','Bumps','Other_Faults']])
#
# File c:\Users\badal\anaconda3\envs\badassh\lib\site-packages\pycaret\classification\functional.py:595, in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     593 exp = _EXPERIMENT_CLASS()
#     594 set_current_experiment(exp)
# --> 595 return exp.setup(
#     596     data=data,
#     597     data_func=data_func,
#     598     target=target,
#     599     index=index,
#     600     train_size=train_size,
#     601     test_data=test_data,
#     602     ordinal_features=ordinal_features,
#     603     numeric_features=numeric_features,
#     604     categorical_features=categorical_features,
#     605     date_features=date_features,
#     606     text_features=text_features,
#     607     ignore_features=ignore_features,
#     608     keep_features=keep_features,
#     609     preprocess=preprocess,
#     610     create_date_columns=create_date_columns,
#     611     imputation_type=imputation_type,
#     612     numeric_imputation=numeric_imputation,
#     613     categorical_imputation=categorical_imputation,
#     614     iterative_imputation_iters=iterative_imputation_iters,
#     615     numeric_iterative_imputer=numeric_iterative_imputer,
#     616     categorical_iterative_imputer=categorical_iterative_imputer,
#     617     text_features_method=text_features_method,
#     618     max_encoding_ohe=max_encoding_ohe,
#     619     encoding_method=encoding_method,
#     620     rare_to_value=rare_to_value,
#     621     rare_value=rare_value,
#     622     polynomial_features=polynomial_features,
#     623     polynomial_degree=polynomial_degree,
#     624     low_variance_threshold=low_variance_threshold,
#     625     group_features=group_features,
#     626     drop_groups=drop_groups,
#     627     remove_multicollinearity=remove_multicollinearity,
#     628     multicollinearity_threshold=multicollinearity_threshold,
#     629     bin_numeric_features=bin_numeric_features,
#     630     remove_outliers=remove_outliers,
#     631     outliers_method=outliers_method,
#     632     outliers_threshold=outliers_threshold,
#     633     fix_imbalance=fix_imbalance,
#     634     fix_imbalance_method=fix_imbalance_method,
#     635     transformation=transformation,
#     636     transformation_method=transformation_method,
#     637     normalize=normalize,
#     638     normalize_method=normalize_method,
#     639     pca=pca,
#     640     pca_method=pca_method,
#     641     pca_components=pca_components,
#     642     feature_selection=feature_selection,
#     643     feature_selection_method=feature_selection_method,
#     644     feature_selection_estimator=feature_selection_estimator,
#     645     n_features_to_select=n_features_to_select,
#     646     custom_pipeline=custom_pipeline,
#     647     custom_pipeline_position=custom_pipeline_position,
#     648     data_split_shuffle=data_split_shuffle,
#     649     data_split_stratify=data_split_stratify,
#     650     fold_strategy=fold_strategy,
#     651     fold=fold,
#     652     fold_shuffle=fold_shuffle,
#     653     fold_groups=fold_groups,
#     654     n_jobs=n_jobs,
#     655     use_gpu=use_gpu,
#     656     html=html,
#     657     session_id=session_id,
#     658     system_log=system_log,
#     659     log_experiment=log_experiment,
#     660     experiment_name=experiment_name,
#     661     experiment_custom_tags=experiment_custom_tags,
#     662     log_plots=log_plots,
#     663     log_profile=log_profile,
#     664     log_data=log_data,
#     665     verbose=verbose,
#     666     memory=memory,
#     667     profile=profile,
#     668     profile_kwargs=profile_kwargs,
#     669 )
#
# File c:\Users\badal\anaconda3\envs\badassh\lib\site-packages\pycaret\classification\oop.py:758, in ClassificationExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     748 self.data_split_shuffle = data_split_shuffle
#     750 self._prepare_folds(
#     751     fold_strategy=fold_strategy,
#     752     fold=fold,
#    (...)
#     755     data_split_shuffle=data_split_shuffle,
#     756 )
# --> 758 self._prepare_train_test(
#     759     train_size=train_size,
#     760     test_data=test_data,
#     761     data_split_stratify=data_split_stratify,
#     762     data_split_shuffle=data_split_shuffle,
#     763 )
#     765 self._prepare_column_types(
#     766     ordinal_features=ordinal_features,
#     767     numeric_features=numeric_features,
#    (...)
#     772     keep_features=keep_features,
#     773 )
#     775 self._set_exp_model_engines(
#     776     container_default_engines=get_container_default_engines(),
#     777     engine=engine,
#     778 )
#
# File c:\Users\badal\anaconda3\envs\badassh\lib\site-packages\pycaret\internal\preprocess\preprocessor.py:236, in Preprocessor._prepare_train_test(self, train_size, test_data, data_split_stratify, data_split_shuffle)
#     233     self.data.index = self.index
#     235 # self.data is already prepared here
# --> 236 train, test = train_test_split(
#     237     self.data,
#     238     train_size=train_size,
#     239     stratify=get_columns_to_stratify_by(
#     240         self.X, self.y, data_split_stratify
#     241     ),
#     242     random_state=self.seed,
#     243     shuffle=data_split_shuffle,
#     244 )
#     245 self.data = self._set_index(pd.concat([train, test]))
#     246 self.idx = [self.data.index[: len(train)], self.data.index[-len(test) :]]
#
# File c:\Users\badal\anaconda3\envs\badassh\lib\site-packages\sklearn\model_selection\_split.py:2583, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2579         CVClass = ShuffleSplit
#    2581     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2583     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2585 return list(
#    2586     chain.from_iterable(
#    2587         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2588     )
#    2589 )
#
# File c:\Users\badal\anaconda3\envs\badassh\lib\site-packages\sklearn\model_selection\_split.py:1689, in BaseShuffleSplit.split(self, X, y, groups)
#    1659 """Generate indices to split data into training and test set.
#    1660
#    1661 Parameters
#    (...)
#    1686 to an integer.
#    1687 """
#    1688 X, y, groups = indexable(X, y, groups)
# -> 1689 for train, test in self._iter_indices(X, y, groups):
#    1690     yield train, test
#
# File c:\Users\badal\anaconda3\envs\badassh\lib\site-packages\sklearn\model_selection\_split.py:2078, in StratifiedShuffleSplit._iter_indices(self, X, y, groups)
#    2076 class_counts = np.bincount(y_indices)
#    2077 if np.min(class_counts) < 2:
# -> 2078     raise ValueError(
#    2079         "The least populated class in y has only 1"
#    2080         " member, which is too few. The minimum"
#    2081         " number of groups for any class cannot"
#    2082         " be less than 2."
#    2083     )
#    2085 if n_train < n_classes:
#    2086     raise ValueError(
#    2087         "The train_size = %d should be greater or "
#    2088         "equal to the number of classes = %d" % (n_train, n_classes)
#    2089     )
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %% [markdown]
# ## Individual Models for Individual Columns

# %%
from pycaret.regression import setup, compare_models

# %%
_ = setup(data=pd.concat([train, pd.DataFrame(target['Pastry'])], axis=1), target = 'Pastry')
# Out:
# <style type="text/css">
# #T_42d03_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_42d03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42d03_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_42d03_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42d03_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42d03_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_42d03_row0_col1" class="data row0 col1" >8442</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42d03_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_42d03_row1_col1" class="data row1 col1" >Pastry</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_42d03_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_42d03_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_42d03_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_42d03_row3_col1" class="data row3 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_42d03_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_42d03_row4_col1" class="data row4 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_42d03_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_42d03_row5_col1" class="data row5 col1" >(13453, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_42d03_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_42d03_row6_col1" class="data row6 col1" >(5766, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_42d03_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_42d03_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_42d03_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_42d03_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_42d03_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_42d03_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_42d03_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_42d03_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_42d03_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_42d03_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_42d03_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_42d03_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_42d03_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_42d03_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_42d03_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_42d03_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_42d03_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_42d03_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_42d03_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_42d03_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_42d03_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_42d03_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_42d03_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_42d03_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_42d03_row18_col1" class="data row18 col1" >3343</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           20:08:38
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
# <style type="text/css">
# #T_c5bad th {
#   text-align: left;
# }
# #T_c5bad_row0_col0, #T_c5bad_row0_col1, #T_c5bad_row0_col6, #T_c5bad_row1_col0, #T_c5bad_row1_col1, #T_c5bad_row1_col2, #T_c5bad_row1_col3, #T_c5bad_row1_col4, #T_c5bad_row1_col5, #T_c5bad_row1_col6, #T_c5bad_row2_col0, #T_c5bad_row2_col1, #T_c5bad_row2_col2, #T_c5bad_row2_col3, #T_c5bad_row2_col4, #T_c5bad_row2_col5, #T_c5bad_row2_col6, #T_c5bad_row3_col0, #T_c5bad_row3_col1, #T_c5bad_row3_col2, #T_c5bad_row3_col3, #T_c5bad_row3_col4, #T_c5bad_row3_col5, #T_c5bad_row3_col6, #T_c5bad_row4_col0, #T_c5bad_row4_col1, #T_c5bad_row4_col2, #T_c5bad_row4_col3, #T_c5bad_row4_col4, #T_c5bad_row4_col5, #T_c5bad_row4_col6, #T_c5bad_row5_col0, #T_c5bad_row5_col1, #T_c5bad_row5_col2, #T_c5bad_row5_col3, #T_c5bad_row5_col4, #T_c5bad_row5_col5, #T_c5bad_row5_col6, #T_c5bad_row6_col0, #T_c5bad_row6_col1, #T_c5bad_row6_col2, #T_c5bad_row6_col3, #T_c5bad_row6_col4, #T_c5bad_row6_col5, #T_c5bad_row6_col6, #T_c5bad_row7_col0, #T_c5bad_row7_col1, #T_c5bad_row7_col2, #T_c5bad_row7_col3, #T_c5bad_row7_col4, #T_c5bad_row7_col5, #T_c5bad_row7_col6, #T_c5bad_row8_col0, #T_c5bad_row8_col1, #T_c5bad_row8_col2, #T_c5bad_row8_col3, #T_c5bad_row8_col4, #T_c5bad_row8_col5, #T_c5bad_row8_col6, #T_c5bad_row9_col0, #T_c5bad_row9_col1, #T_c5bad_row9_col2, #T_c5bad_row9_col3, #T_c5bad_row9_col4, #T_c5bad_row9_col5, #T_c5bad_row9_col6, #T_c5bad_row10_col0, #T_c5bad_row10_col1, #T_c5bad_row10_col2, #T_c5bad_row10_col3, #T_c5bad_row10_col4, #T_c5bad_row10_col5, #T_c5bad_row10_col6, #T_c5bad_row11_col0, #T_c5bad_row11_col1, #T_c5bad_row11_col2, #T_c5bad_row11_col3, #T_c5bad_row11_col4, #T_c5bad_row11_col5, #T_c5bad_row11_col6, #T_c5bad_row12_col0, #T_c5bad_row12_col1, #T_c5bad_row12_col2, #T_c5bad_row12_col3, #T_c5bad_row12_col4, #T_c5bad_row12_col5, #T_c5bad_row12_col6, #T_c5bad_row13_col0, #T_c5bad_row13_col1, #T_c5bad_row13_col2, #T_c5bad_row13_col3, #T_c5bad_row13_col4, #T_c5bad_row13_col5, #T_c5bad_row13_col6, #T_c5bad_row14_col0, #T_c5bad_row14_col1, #T_c5bad_row14_col2, #T_c5bad_row14_col3, #T_c5bad_row14_col4, #T_c5bad_row14_col5, #T_c5bad_row14_col6, #T_c5bad_row15_col0, #T_c5bad_row15_col1, #T_c5bad_row15_col2, #T_c5bad_row15_col3, #T_c5bad_row15_col4, #T_c5bad_row15_col5, #T_c5bad_row15_col6, #T_c5bad_row16_col0, #T_c5bad_row16_col2, #T_c5bad_row16_col3, #T_c5bad_row16_col4, #T_c5bad_row16_col5, #T_c5bad_row16_col6, #T_c5bad_row17_col0, #T_c5bad_row17_col1, #T_c5bad_row17_col2, #T_c5bad_row17_col3, #T_c5bad_row17_col4, #T_c5bad_row17_col5, #T_c5bad_row18_col0, #T_c5bad_row18_col1, #T_c5bad_row18_col2, #T_c5bad_row18_col3, #T_c5bad_row18_col4, #T_c5bad_row18_col5, #T_c5bad_row18_col6, #T_c5bad_row19_col0, #T_c5bad_row19_col1, #T_c5bad_row19_col2, #T_c5bad_row19_col3, #T_c5bad_row19_col4, #T_c5bad_row19_col5, #T_c5bad_row19_col6 {
#   text-align: left;
# }
# #T_c5bad_row0_col2, #T_c5bad_row0_col3, #T_c5bad_row0_col4, #T_c5bad_row0_col5, #T_c5bad_row16_col1, #T_c5bad_row17_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c5bad_row0_col7, #T_c5bad_row1_col7, #T_c5bad_row2_col7, #T_c5bad_row3_col7, #T_c5bad_row4_col7, #T_c5bad_row5_col7, #T_c5bad_row6_col7, #T_c5bad_row7_col7, #T_c5bad_row8_col7, #T_c5bad_row9_col7, #T_c5bad_row10_col7, #T_c5bad_row11_col7, #T_c5bad_row12_col7, #T_c5bad_row13_col7, #T_c5bad_row15_col7, #T_c5bad_row16_col7, #T_c5bad_row17_col7, #T_c5bad_row18_col7, #T_c5bad_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c5bad_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c5bad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5bad_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c5bad_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c5bad_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c5bad_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c5bad_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c5bad_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c5bad_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c5bad_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5bad_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_c5bad_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_c5bad_row0_col1" class="data row0 col1" >0.1208</td>
#       <td id="T_c5bad_row0_col2" class="data row0 col2" >0.0588</td>
#       <td id="T_c5bad_row0_col3" class="data row0 col3" >0.2425</td>
#       <td id="T_c5bad_row0_col4" class="data row0 col4" >0.1457</td>
#       <td id="T_c5bad_row0_col5" class="data row0 col5" >0.1699</td>
#       <td id="T_c5bad_row0_col6" class="data row0 col6" >0.7906</td>
#       <td id="T_c5bad_row0_col7" class="data row0 col7" >4.1710</td>
#     </tr>
#     <tr>
#       <th id="T_c5bad_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_c5bad_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c5bad_row1_col1" class="data row1 col1" >0.1175</td>
#       <td id="T_c5bad_row1_col2" class="data row1 col2" >0.0595</td>
#       <td id="T_c5bad_row1_col3" class="data row1 col3" >0.2438</td>
#       <td id="T_c5bad_row1_col4" class="data row1 col4" >0.1362</td>
#       <td id="T_c5bad_row1_col5" class="data row1 col5" >0.1717</td>
#       <td id="T_c5bad_row1_col6" class="data row1 col6" >0.7635</td>
#       <td id="T_c5bad_row1_col7" class="data row1 col7" >0.7480</td>
#     </tr>
#     <tr>
#       <th id="T_c5bad_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_c5bad_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_c5bad_row2_col1" class="data row2 col1" >0.1222</td>
#       <td id="T_c5bad_row2_col2" class="data row2 col2" >0.0600</td>
#       <td id="T_c5bad_row2_col3" class="data row2 col3" >0.2448</td>
#       <td id="T_c5bad_row2_col4" class="data row2 col4" >0.1293</td>
#       <td id="T_c5bad_row2_col5" class="data row2 col5" >0.1727</td>
#       <td id="T_c5bad_row2_col6" class="data row2 col6" >0.7647</td>
#       <td id="T_c5bad_row2_col7" class="data row2 col7" >9.0360</td>
#     </tr>
#     <tr>
#       <th id="T_c5bad_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_c5bad_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_c5bad_row3_col1" class="data row3 col1" >0.1260</td>
#       <td id="T_c5bad_row3_col2" class="data row3 col2" >0.0610</td>
#       <td id="T_c5bad_row3_col3" class="data row3 col3" >0.2469</td>
#       <td id="T_c5bad_row3_col4" class="data row3 col4" >0.1142</td>
#       <td id="T_c5bad_row3_col5" class="data row3 col5" >0.1757</td>
#       <td id="T_c5bad_row3_col6" class="data row3 col6" >0.7726</td>
#       <td id="T_c5bad_row3_col7" class="data row3 col7" >1.6660</td>
#     </tr>
#     <tr>
#       <th id="T_c5bad_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_c5bad_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_c5bad_row4_col1" class="data row4 col1" >0.1364</td>
#       <td id="T_c5bad_row4_col2" class="data row4 col2" >0.0617</td>
#       <td id="T_c5bad_row4_col3" class="data row4 col3" >0.2484</td>
#       <td id="T_c5bad_row4_col4" class="data row4 col4" >0.1034</td>
#       <td id="T_c5bad_row4_col5" class="data row4 col5" >0.1745</td>
#       <td id="T_c5bad_row4_col6" class="data row4 col6" >0.8281</td>
#       <td id="T_c5bad_row4_col7" class="data row4 col7" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_c5bad_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_c5bad_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_c5bad_row5_col1" class="data row5 col1" >0.1364</td>
#       <td id="T_c5bad_row5_col2" class="data row5 col2" >0.0617</td>
#       <td id="T_c5bad_row5_col3" class="data row5 col3" >0.2484
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=8442, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
_ = setup(data=pd.concat([train, pd.DataFrame(target['Z_Scratch'])], axis=1), target = 'Z_Scratch')
# Out:
# <style type="text/css">
# #T_ace8a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ace8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ace8a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ace8a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ace8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ace8a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ace8a_row0_col1" class="data row0 col1" >2076</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ace8a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ace8a_row1_col1" class="data row1 col1" >Z_Scratch</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ace8a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ace8a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ace8a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ace8a_row3_col1" class="data row3 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ace8a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ace8a_row4_col1" class="data row4 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ace8a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ace8a_row5_col1" class="data row5 col1" >(13453, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ace8a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ace8a_row6_col1" class="data row6 col1" >(5766, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ace8a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ace8a_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ace8a_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_ace8a_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ace8a_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_ace8a_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ace8a_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_ace8a_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ace8a_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_ace8a_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ace8a_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_ace8a_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ace8a_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_ace8a_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ace8a_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_ace8a_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ace8a_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_ace8a_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ace8a_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_ace8a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ace8a_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_ace8a_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ace8a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ace8a_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_ace8a_row18_col1" class="data row18 col1" >81f9</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=2076, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#               subsample_for_bin=200000, subsample_freq=0)

# %%
_ = setup(data=pd.concat([train, pd.DataFrame(target['K_Scatch'])], axis=1), target = 'K_Scatch')
# Out:
# <style type="text/css">
# #T_ee591_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ee591">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee591_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ee591_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee591_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee591_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ee591_row0_col1" class="data row0 col1" >295</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ee591_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ee591_row1_col1" class="data row1 col1" >K_Scatch</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ee591_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ee591_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ee591_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ee591_row3_col1" class="data row3 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ee591_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ee591_row4_col1" class="data row4 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ee591_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ee591_row5_col1" class="data row5 col1" >(13453, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ee591_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ee591_row6_col1" class="data row6 col1" >(5766, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ee591_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ee591_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ee591_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_ee591_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ee591_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_ee591_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ee591_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_ee591_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ee591_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_ee591_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ee591_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_ee591_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ee591_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_ee591_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ee591_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_ee591_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ee591_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_ee591_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ee591_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_ee591_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ee591_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_ee591_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ee591_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ee591_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_ee591_row18_col1" class="data row18 col1" >a6bf</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              20:17:36
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_17d99 th {
#   text-align: left;
# }
# #T_17d99_row0_col0, #T_17d99_row0_col1, #T_17d99_row0_col6, #T_17d99_row1_col0, #T_17d99_row1_col1, #T_17d99_row1_col2, #T_17d99_row1_col3, #T_17d99_row1_col4, #T_17d99_row1_col5, #T_17d99_row1_col6, #T_17d99_row2_col0, #T_17d99_row2_col1, #T_17d99_row2_col2, #T_17d99_row2_col3, #T_17d99_row2_col4, #T_17d99_row2_col5, #T_17d99_row2_col6, #T_17d99_row3_col0, #T_17d99_row3_col1, #T_17d99_row3_col2, #T_17d99_row3_col3, #T_17d99_row3_col4, #T_17d99_row3_col5, #T_17d99_row3_col6, #T_17d99_row4_col0, #T_17d99_row4_col1, #T_17d99_row4_col2, #T_17d99_row4_col3, #T_17d99_row4_col4, #T_17d99_row4_col5, #T_17d99_row4_col6, #T_17d99_row5_col0, #T_17d99_row5_col1, #T_17d99_row5_col2, #T_17d99_row5_col3, #T_17d99_row5_col4, #T_17d99_row5_col5, #T_17d99_row5_col6, #T_17d99_row6_col0, #T_17d99_row6_col2, #T_17d99_row6_col3, #T_17d99_row6_col4, #T_17d99_row6_col5, #T_17d99_row7_col0, #T_17d99_row7_col1, #T_17d99_row7_col2, #T_17d99_row7_col3, #T_17d99_row7_col4, #T_17d99_row7_col5, #T_17d99_row7_col6, #T_17d99_row8_col0, #T_17d99_row8_col1, #T_17d99_row8_col2, #T_17d99_row8_col3, #T_17d99_row8_col4, #T_17d99_row8_col5, #T_17d99_row8_col6, #T_17d99_row9_col0, #T_17d99_row9_col1, #T_17d99_row9_col2, #T_17d99_row9_col3, #T_17d99_row9_col4, #T_17d99_row9_col5, #T_17d99_row9_col6, #T_17d99_row10_col0, #T_17d99_row10_col1, #T_17d99_row10_col2, #T_17d99_row10_col3, #T_17d99_row10_col4, #T_17d99_row10_col5, #T_17d99_row10_col6, #T_17d99_row11_col0, #T_17d99_row11_col1, #T_17d99_row11_col2, #T_17d99_row11_col3, #T_17d99_row11_col4, #T_17d99_row11_col5, #T_17d99_row11_col6, #T_17d99_row12_col0, #T_17d99_row12_col1, #T_17d99_row12_col2, #T_17d99_row12_col3, #T_17d99_row12_col4, #T_17d99_row12_col5, #T_17d99_row12_col6, #T_17d99_row13_col0, #T_17d99_row13_col1, #T_17d99_row13_col2, #T_17d99_row13_col3, #T_17d99_row13_col4, #T_17d99_row13_col5, #T_17d99_row13_col6, #T_17d99_row14_col0, #T_17d99_row14_col1, #T_17d99_row14_col2, #T_17d99_row14_col3, #T_17d99_row14_col4, #T_17d99_row14_col5, #T_17d99_row14_col6, #T_17d99_row15_col0, #T_17d99_row15_col1, #T_17d99_row15_col2, #T_17d99_row15_col3, #T_17d99_row15_col4, #T_17d99_row15_col5, #T_17d99_row15_col6, #T_17d99_row16_col0, #T_17d99_row16_col1, #T_17d99_row16_col2, #T_17d99_row16_col3, #T_17d99_row16_col4, #T_17d99_row16_col5, #T_17d99_row16_col6, #T_17d99_row17_col0, #T_17d99_row17_col1, #T_17d99_row17_col2, #T_17d99_row17_col3, #T_17d99_row17_col4, #T_17d99_row17_col5, #T_17d99_row17_col6, #T_17d99_row18_col0, #T_17d99_row18_col1, #T_17d99_row18_col2, #T_17d99_row18_col3, #T_17d99_row18_col4, #T_17d99_row18_col5, #T_17d99_row18_col6, #T_17d99_row19_col0, #T_17d99_row19_col1, #T_17d99_row19_col2, #T_17d99_row19_col3, #T_17d99_row19_col4, #T_17d99_row19_col5, #T_17d99_row19_col6 {
#   text-align: left;
# }
# #T_17d99_row0_col2, #T_17d99_row0_col3, #T_17d99_row0_col4, #T_17d99_row0_col5, #T_17d99_row6_col1, #T_17d99_row6_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_17d99_row0_col7, #T_17d99_row1_col7, #T_17d99_row2_col7, #T_17d99_row3_col7, #T_17d99_row4_col7, #T_17d99_row5_col7, #T_17d99_row6_col7, #T_17d99_row7_col7, #T_17d99_row8_col7, #T_17d99_row9_col7, #T_17d99_row10_col7, #T_17d99_row11_col7, #T_17d99_row12_col7, #T_17d99_row13_col7, #T_17d99_row14_col7, #T_17d99_row15_col7, #T_17d99_row16_col7, #T_17d99_row18_col7, #T_17d99_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_17d99_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_17d99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17d99_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_17d99_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_17d99_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_17d99_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_17d99_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_17d99_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_17d99_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_17d99_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17d99_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_17d99_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_17d99_row0_col1" class="data row0 col1" >0.0679</td>
#       <td id="T_17d99_row0_col2" class="data row0 col2" >0.0332</td>
#       <td id="T_17d99_row0_col3" class="data row0 col3" >0.1817</td>
#       <td id="T_17d99_row0_col4" class="data row0 col4" >0.7735</td>
#       <td id="T_17d99_row0_col5" class="data row0 col5" >0.1261</td>
#       <td id="T_17d99_row0_col6" class="data row0 col6" >0.1823</td>
#       <td id="T_17d99_row0_col7" class="data row0 col7" >2.6240</td>
#     </tr>
#     <tr>
#       <th id="T_17d99_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_17d99_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_17d99_row1_col1" class="data row1 col1" >0.0699</td>
#       <td id="T_17d99_row1_col2" class="data row1 col2" >0.0335</td>
#       <td id="T_17d99_row1_col3" class="data row1 col3" >0.1827</td>
#       <td id="T_17d99_row1_col4" class="data row1 col4" >0.7713</td>
#       <td id="T_17d99_row1_col5" class="data row1 col5" >0.1271</td>
#       <td id="T_17d99_row1_col6" class="data row1 col6" >0.1805</td>
#       <td id="T_17d99_row1_col7" class="data row1 col7" >7.2040</td>
#     </tr>
#     <tr>
#       <th id="T_17d99_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_17d99_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_17d99_row2_col1" class="data row2 col1" >0.0680</td>
#       <td id="T_17d99_row2_col2" class="data row2 col2" >0.0335</td>
#       <td id="T_17d99_row2_col3" class="data row2 col3" >0.1828</td>
#       <td id="T_17d99_row2_col4" class="data row2 col4" >0.7712</td>
#       <td id="T_17d99_row2_col5" class="data row2 col5" >0.1276</td>
#       <td id="T_17d99_row2_col6" class="data row2 col6" >0.1866</td>
#       <td id="T_17d99_row2_col7" class="data row2 col7" >1.0930</td>
#     </tr>
#     <tr>
#       <th id="T_17d99_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_17d99_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_17d99_row3_col1" class="data row3 col1" >0.0664</td>
#       <td id="T_17d99_row3_col2" class="data row3 col2" >0.0336</td>
#       <td id="T_17d99_row3_col3" class="data row3 col3" >0.1829</td>
#       <td id="T_17d99_row3_col4" class="data row3 col4" >0.7706</td>
#       <td id="T_17d99_row3_col5" class="data row3 col5" >0.1270</td>
#       <td id="T_17d99_row3_col6" class="data row3 col6" >0.1809</td>
#       <td id="T_17d99_row3_col7" class="data row3 col7" >0.2930</td>
#     </tr>
#     <tr>
#       <th id="T_17d99_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_17d99_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_17d99_row4_col1" class="data row4 col1" >0.0682</td>
#       <td id="T_17d99_row4_col2" class="data row4 col2" >0.0344</td>
#       <td id="T_17d99_row4_col3" class="data row4 col3" >0.1852</td>
#       <td id="T_17d99_row4_col4" class="data row4 col4" >0.7654</td>
#       <td id="T_17d99_row4_col5" class="data row4 col5" >0.1297</td>
#       <td id="T_17d99_row4_col6" class="data row4 col6" >0.1887</td>
#       <td id="T_17d99_row4_col7" class="data row4 col7" >5.9800</td>
#     </tr>
#     <tr>
#       <th id="T_17d99_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_17d99_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_17d99_row5_col1" class="data row5 col1" >0.0739</td>
#       <td id="T_17d99_row5_col2" class="data row5 col2" >0.0382</td>
#       <td id="T_17d99_row5_col3" class="data r
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=295, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
_ = setup(data=pd.concat([train, pd.DataFrame(target['Stains'])], axis=1), target = 'Stains')
# Out:
# <style type="text/css">
# #T_b37af_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b37af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b37af_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b37af_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b37af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b37af_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b37af_row0_col1" class="data row0 col1" >4136</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b37af_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b37af_row1_col1" class="data row1 col1" >Stains</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b37af_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b37af_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b37af_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b37af_row3_col1" class="data row3 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b37af_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b37af_row4_col1" class="data row4 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b37af_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b37af_row5_col1" class="data row5 col1" >(13453, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b37af_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b37af_row6_col1" class="data row6 col1" >(5766, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b37af_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b37af_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b37af_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b37af_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b37af_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b37af_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b37af_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b37af_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b37af_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b37af_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b37af_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b37af_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b37af_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b37af_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b37af_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b37af_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b37af_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b37af_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b37af_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b37af_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b37af_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b37af_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b37af_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b37af_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b37af_row18_col1" class="data row18 col1" >bba5</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# Empty DataFrame
# Columns: [Model, MAE, MSE, RMSE, R2, RMSLE, MAPE, TT (Sec)]
# Index: []

# %%
_ = setup(data=pd.concat([train, pd.DataFrame(target['Dirtiness'])], axis=1), target = 'Dirtiness')
# Out:
# <style type="text/css">
# #T_47073_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_47073">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47073_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_47073_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47073_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47073_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_47073_row0_col1" class="data row0 col1" >4767</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47073_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_47073_row1_col1" class="data row1 col1" >Dirtiness</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47073_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_47073_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_47073_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_47073_row3_col1" class="data row3 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_47073_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_47073_row4_col1" class="data row4 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_47073_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_47073_row5_col1" class="data row5 col1" >(13453, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_47073_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_47073_row6_col1" class="data row6 col1" >(5766, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_47073_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_47073_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_47073_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_47073_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_47073_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_47073_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_47073_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_47073_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_47073_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_47073_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_47073_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_47073_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_47073_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_47073_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_47073_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_47073_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_47073_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_47073_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_47073_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_47073_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_47073_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_47073_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_47073_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_47073_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_47073_row18_col1" class="data row18 col1" >eb85</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_2a19a th {
#   text-align: left;
# }
# #T_2a19a_row0_col0, #T_2a19a_row0_col1, #T_2a19a_row0_col6, #T_2a19a_row1_col0, #T_2a19a_row1_col1, #T_2a19a_row1_col2, #T_2a19a_row1_col3, #T_2a19a_row1_col4, #T_2a19a_row1_col5, #T_2a19a_row1_col6, #T_2a19a_row2_col0, #T_2a19a_row2_col1, #T_2a19a_row2_col2, #T_2a19a_row2_col3, #T_2a19a_row2_col4, #T_2a19a_row2_col5, #T_2a19a_row2_col6, #T_2a19a_row3_col0, #T_2a19a_row3_col1, #T_2a19a_row3_col2, #T_2a19a_row3_col3, #T_2a19a_row3_col4, #T_2a19a_row3_col5, #T_2a19a_row3_col6, #T_2a19a_row4_col0, #T_2a19a_row4_col1, #T_2a19a_row4_col2, #T_2a19a_row4_col3, #T_2a19a_row4_col4, #T_2a19a_row4_col5, #T_2a19a_row4_col6, #T_2a19a_row5_col0, #T_2a19a_row5_col1, #T_2a19a_row5_col2, #T_2a19a_row5_col3, #T_2a19a_row5_col4, #T_2a19a_row5_col5, #T_2a19a_row5_col6, #T_2a19a_row6_col0, #T_2a19a_row6_col1, #T_2a19a_row6_col2, #T_2a19a_row6_col3, #T_2a19a_row6_col4, #T_2a19a_row6_col5, #T_2a19a_row6_col6, #T_2a19a_row7_col0, #T_2a19a_row7_col1, #T_2a19a_row7_col2, #T_2a19a_row7_col3, #T_2a19a_row7_col4, #T_2a19a_row7_col5, #T_2a19a_row7_col6, #T_2a19a_row8_col0, #T_2a19a_row8_col1, #T_2a19a_row8_col2, #T_2a19a_row8_col3, #T_2a19a_row8_col4, #T_2a19a_row8_col5, #T_2a19a_row8_col6, #T_2a19a_row9_col0, #T_2a19a_row9_col1, #T_2a19a_row9_col2, #T_2a19a_row9_col3, #T_2a19a_row9_col4, #T_2a19a_row9_col5, #T_2a19a_row9_col6, #T_2a19a_row10_col0, #T_2a19a_row10_col1, #T_2a19a_row10_col2, #T_2a19a_row10_col3, #T_2a19a_row10_col4, #T_2a19a_row10_col5, #T_2a19a_row10_col6, #T_2a19a_row11_col0, #T_2a19a_row11_col1, #T_2a19a_row11_col2, #T_2a19a_row11_col3, #T_2a19a_row11_col4, #T_2a19a_row11_col5, #T_2a19a_row11_col6, #T_2a19a_row12_col0, #T_2a19a_row12_col1, #T_2a19a_row12_col2, #T_2a19a_row12_col3, #T_2a19a_row12_col4, #T_2a19a_row12_col5, #T_2a19a_row12_col6, #T_2a19a_row13_col0, #T_2a19a_row13_col1, #T_2a19a_row13_col2, #T_2a19a_row13_col3, #T_2a19a_row13_col4, #T_2a19a_row13_col5, #T_2a19a_row13_col6, #T_2a19a_row14_col0, #T_2a19a_row14_col2, #T_2a19a_row14_col3, #T_2a19a_row14_col4, #T_2a19a_row14_col5, #T_2a19a_row14_col6, #T_2a19a_row15_col0, #T_2a19a_row15_col1, #T_2a19a_row15_col2, #T_2a19a_row15_col3, #T_2a19a_row15_col4, #T_2a19a_row15_col5, #T_2a19a_row15_col6, #T_2a19a_row16_col0, #T_2a19a_row16_col1, #T_2a19a_row16_col2, #T_2a19a_row16_col3, #T_2a19a_row16_col4, #T_2a19a_row16_col5, #T_2a19a_row16_col6, #T_2a19a_row17_col0, #T_2a19a_row17_col1, #T_2a19a_row17_col2, #T_2a19a_row17_col3, #T_2a19a_row17_col4, #T_2a19a_row17_col5, #T_2a19a_row18_col0, #T_2a19a_row18_col1, #T_2a19a_row18_col2, #T_2a19a_row18_col3, #T_2a19a_row18_col4, #T_2a19a_row18_col5, #T_2a19a_row18_col6, #T_2a19a_row19_col0, #T_2a19a_row19_col1, #T_2a19a_row19_col2, #T_2a19a_row19_col3, #T_2a19a_row19_col4, #T_2a19a_row19_col5, #T_2a19a_row19_col6 {
#   text-align: left;
# }
# #T_2a19a_row0_col2, #T_2a19a_row0_col3, #T_2a19a_row0_col4, #T_2a19a_row0_col5, #T_2a19a_row14_col1, #T_2a19a_row17_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2a19a_row0_col7, #T_2a19a_row1_col7, #T_2a19a_row2_col7, #T_2a19a_row3_col7, #T_2a19a_row4_col7, #T_2a19a_row5_col7, #T_2a19a_row6_col7, #T_2a19a_row7_col7, #T_2a19a_row8_col7, #T_2a19a_row10_col7, #T_2a19a_row11_col7, #T_2a19a_row12_col7, #T_2a19a_row13_col7, #T_2a19a_row14_col7, #T_2a19a_row15_col7, #T_2a19a_row16_col7, #T_2a19a_row17_col7, #T_2a19a_row18_col7, #T_2a19a_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2a19a_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2a19a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a19a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2a19a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2a19a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2a19a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2a19a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2a19a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2a19a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2a19a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a19a_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_2a19a_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_2a19a_row0_col1" class="data row0 col1" >0.0464</td>
#       <td id="T_2a19a_row0_col2" class="data row0 col2" >0.0225</td>
#       <td id="T_2a19a_row0_col3" class="data row0 col3" >0.1496</td>
#       <td id="T_2a19a_row0_col4" class="data row0 col4" >0.0939</td>
#       <td id="T_2a19a_row0_col5" class="data row0 col5" >0.1047</td>
#       <td id="T_2a19a_row0_col6" class="data row0 col6" >0.8673</td>
#       <td id="T_2a19a_row0_col7" class="data row0 col7" >3.0160</td>
#     </tr>
#     <tr>
#       <th id="T_2a19a_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_2a19a_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_2a19a_row1_col1" class="data row1 col1" >0.0499</td>
#       <td id="T_2a19a_row1_col2" class="data row1 col2" >0.0228</td>
#       <td id="T_2a19a_row1_col3" class="data row1 col3" >0.1508</td>
#       <td id="T_2a19a_row1_col4" class="data row1 col4" >0.0775</td>
#       <td id="T_2a19a_row1_col5" class="data row1 col5" >0.1064</td>
#       <td id="T_2a19a_row1_col6" class="data row1 col6" >0.8493</td>
#       <td id="T_2a19a_row1_col7" class="data row1 col7" >6.8030</td>
#     </tr>
#     <tr>
#       <th id="T_2a19a_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_2a19a_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2a19a_row2_col1" class="data row2 col1" >0.0486</td>
#       <td id="T_2a19a_row2_col2" class="data row2 col2" >0.0234</td>
#       <td id="T_2a19a_row2_col3" class="data row2 col3" >0.1529</td>
#       <td id="T_2a19a_row2_col4" class="data row2 col4" >0.0532</td>
#       <td id="T_2a19a_row2_col5" class="data row2 col5" >0.1082</td>
#       <td id="T_2a19a_row2_col6" class="data row2 col6" >0.8489</td>
#       <td id="T_2a19a_row2_col7" class="data row2 col7" >0.3660</td>
#     </tr>
#     <tr>
#       <th id="T_2a19a_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_2a19a_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_2a19a_row3_col1" class="data row3 col1" >0.0536</td>
#       <td id="T_2a19a_row3_col2" class="data row3 col2" >0.0236</td>
#       <td id="T_2a19a_row3_col3" class="data row3 col3" >0.1534</td>
#       <td id="T_2a19a_row3_col4" class="data row3 col4" >0.0482</td>
#       <td id="T_2a19a_row3_col5" class="data row3 col5" >0.1071</td>
#       <td id="T_2a19a_row3_col6" class="data row3 col6" >0.9247</td>
#       <td id="T_2a19a_row3_col7" class="data row3 col7" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_2a19a_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_2a19a_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_2a19a_row4_col1" class="data row4 col1" >0.0537</td>
#       <td id="T_2a19a_row4_col2" class="data row4 col2" >0.0236</td>
#       <td id="T_2a19a_row4_col3" class="data row4 col3" >0.1534</td>
#       <td id="T_2a19a_row4_col4" class="data row4 col4" >0.0481</td>
#       <td id="T_2a19a_row4_col5" class="data row4 col5" >0.1071</td>
#       <td id="T_2a19a_row4_col6" class="data row4 col6" >0.9241</td>
#       <td id="T_2a19a_row4_col7" class="data row4 col7" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_2a19a_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_2a19a_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_2a19a_row5_col1" class="data row5 col1" >0.0530</td>
#       <td id="T_2a19a_row5_col2" class="data row5 col2" >0.0237</td>
#       <td id="T_2a19a_row5_col3" class="data row5 col3" >0.1536</td>
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=4767, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
_ = setup(data=pd.concat([train, pd.DataFrame(target['Bumps'])], axis=1), target = 'Bumps')
# Out:
# <style type="text/css">
# #T_e2c3a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e2c3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2c3a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e2c3a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2c3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2c3a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e2c3a_row0_col1" class="data row0 col1" >6764</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2c3a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e2c3a_row1_col1" class="data row1 col1" >Bumps</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e2c3a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e2c3a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e2c3a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e2c3a_row3_col1" class="data row3 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e2c3a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e2c3a_row4_col1" class="data row4 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e2c3a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e2c3a_row5_col1" class="data row5 col1" >(13453, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e2c3a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e2c3a_row6_col1" class="data row6 col1" >(5766, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e2c3a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e2c3a_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e2c3a_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e2c3a_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e2c3a_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e2c3a_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e2c3a_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e2c3a_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e2c3a_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e2c3a_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e2c3a_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e2c3a_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e2c3a_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e2c3a_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e2c3a_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e2c3a_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e2c3a_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e2c3a_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e2c3a_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e2c3a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e2c3a_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e2c3a_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e2c3a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e2c3a_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e2c3a_row18_col1" class="data row18 col1" >7b90</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_6ddcb th {
#   text-align: left;
# }
# #T_6ddcb_row0_col0, #T_6ddcb_row0_col1, #T_6ddcb_row0_col6, #T_6ddcb_row1_col0, #T_6ddcb_row1_col1, #T_6ddcb_row1_col2, #T_6ddcb_row1_col3, #T_6ddcb_row1_col4, #T_6ddcb_row1_col6, #T_6ddcb_row2_col0, #T_6ddcb_row2_col1, #T_6ddcb_row2_col2, #T_6ddcb_row2_col3, #T_6ddcb_row2_col4, #T_6ddcb_row2_col5, #T_6ddcb_row2_col6, #T_6ddcb_row3_col0, #T_6ddcb_row3_col1, #T_6ddcb_row3_col2, #T_6ddcb_row3_col3, #T_6ddcb_row3_col4, #T_6ddcb_row3_col5, #T_6ddcb_row3_col6, #T_6ddcb_row4_col0, #T_6ddcb_row4_col1, #T_6ddcb_row4_col2, #T_6ddcb_row4_col3, #T_6ddcb_row4_col4, #T_6ddcb_row4_col5, #T_6ddcb_row4_col6, #T_6ddcb_row5_col0, #T_6ddcb_row5_col1, #T_6ddcb_row5_col2, #T_6ddcb_row5_col3, #T_6ddcb_row5_col4, #T_6ddcb_row5_col5, #T_6ddcb_row5_col6, #T_6ddcb_row6_col0, #T_6ddcb_row6_col1, #T_6ddcb_row6_col2, #T_6ddcb_row6_col3, #T_6ddcb_row6_col4, #T_6ddcb_row6_col5, #T_6ddcb_row6_col6, #T_6ddcb_row7_col0, #T_6ddcb_row7_col1, #T_6ddcb_row7_col2, #T_6ddcb_row7_col3, #T_6ddcb_row7_col4, #T_6ddcb_row7_col5, #T_6ddcb_row7_col6, #T_6ddcb_row8_col0, #T_6ddcb_row8_col1, #T_6ddcb_row8_col2, #T_6ddcb_row8_col3, #T_6ddcb_row8_col4, #T_6ddcb_row8_col5, #T_6ddcb_row8_col6, #T_6ddcb_row9_col0, #T_6ddcb_row9_col1, #T_6ddcb_row9_col2, #T_6ddcb_row9_col3, #T_6ddcb_row9_col4, #T_6ddcb_row9_col5, #T_6ddcb_row9_col6, #T_6ddcb_row10_col0, #T_6ddcb_row10_col1, #T_6ddcb_row10_col2, #T_6ddcb_row10_col3, #T_6ddcb_row10_col4, #T_6ddcb_row10_col5, #T_6ddcb_row10_col6, #T_6ddcb_row11_col0, #T_6ddcb_row11_col1, #T_6ddcb_row11_col2, #T_6ddcb_row11_col3, #T_6ddcb_row11_col4, #T_6ddcb_row11_col5, #T_6ddcb_row12_col0, #T_6ddcb_row12_col1, #T_6ddcb_row12_col2, #T_6ddcb_row12_col3, #T_6ddcb_row12_col4, #T_6ddcb_row12_col5, #T_6ddcb_row12_col6, #T_6ddcb_row13_col0, #T_6ddcb_row13_col1, #T_6ddcb_row13_col2, #T_6ddcb_row13_col3, #T_6ddcb_row13_col4, #T_6ddcb_row13_col5, #T_6ddcb_row13_col6, #T_6ddcb_row14_col0, #T_6ddcb_row14_col1, #T_6ddcb_row14_col2, #T_6ddcb_row14_col3, #T_6ddcb_row14_col4, #T_6ddcb_row14_col5, #T_6ddcb_row14_col6, #T_6ddcb_row15_col0, #T_6ddcb_row15_col1, #T_6ddcb_row15_col2, #T_6ddcb_row15_col3, #T_6ddcb_row15_col4, #T_6ddcb_row15_col5, #T_6ddcb_row15_col6, #T_6ddcb_row16_col0, #T_6ddcb_row16_col1, #T_6ddcb_row16_col2, #T_6ddcb_row16_col3, #T_6ddcb_row16_col4, #T_6ddcb_row16_col5, #T_6ddcb_row16_col6, #T_6ddcb_row17_col0, #T_6ddcb_row17_col1, #T_6ddcb_row17_col2, #T_6ddcb_row17_col3, #T_6ddcb_row17_col4, #T_6ddcb_row17_col5, #T_6ddcb_row17_col6, #T_6ddcb_row18_col0, #T_6ddcb_row18_col2, #T_6ddcb_row18_col3, #T_6ddcb_row18_col4, #T_6ddcb_row18_col5, #T_6ddcb_row18_col6, #T_6ddcb_row19_col0, #T_6ddcb_row19_col1, #T_6ddcb_row19_col2, #T_6ddcb_row19_col3, #T_6ddcb_row19_col4, #T_6ddcb_row19_col5, #T_6ddcb_row19_col6 {
#   text-align: left;
# }
# #T_6ddcb_row0_col2, #T_6ddcb_row0_col3, #T_6ddcb_row0_col4, #T_6ddcb_row0_col5, #T_6ddcb_row1_col5, #T_6ddcb_row11_col6, #T_6ddcb_row18_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6ddcb_row0_col7, #T_6ddcb_row1_col7, #T_6ddcb_row2_col7, #T_6ddcb_row3_col7, #T_6ddcb_row4_col7, #T_6ddcb_row5_col7, #T_6ddcb_row6_col7, #T_6ddcb_row8_col7, #T_6ddcb_row9_col7, #T_6ddcb_row10_col7, #T_6ddcb_row11_col7, #T_6ddcb_row12_col7, #T_6ddcb_row13_col7, #T_6ddcb_row14_col7, #T_6ddcb_row15_col7, #T_6ddcb_row16_col7, #T_6ddcb_row17_col7, #T_6ddcb_row18_col7, #T_6ddcb_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6ddcb_row7_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6ddcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ddcb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6ddcb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6ddcb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6ddcb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6ddcb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6ddcb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6ddcb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6ddcb_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ddcb_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_6ddcb_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6ddcb_row0_col1" class="data row0 col1" >0.2945</td>
#       <td id="T_6ddcb_row0_col2" class="data row0 col2" >0.1495</td>
#       <td id="T_6ddcb_row0_col3" class="data row0 col3" >0.3866</td>
#       <td id="T_6ddcb_row0_col4" class="data row0 col4" >0.1962</td>
#       <td id="T_6ddcb_row0_col5" class="data row0 col5" >0.2718</td>
#       <td id="T_6ddcb_row0_col6" class="data row0 col6" >0.5892</td>
#       <td id="T_6ddcb_row0_col7" class="data row0 col7" >0.4120</td>
#     </tr>
#     <tr>
#       <th id="T_6ddcb_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_6ddcb_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6ddcb_row1_col1" class="data row1 col1" >0.3042</td>
#       <td id="T_6ddcb_row1_col2" class="data row1 col2" >0.1496</td>
#       <td id="T_6ddcb_row1_col3" class="data row1 col3" >0.3867</td>
#       <td id="T_6ddcb_row1_col4" class="data row1 col4" >0.1959</td>
#       <td id="T_6ddcb_row1_col5" class="data row1 col5" >0.2718</td>
#       <td id="T_6ddcb_row1_col6" class="data row1 col6" >0.6095</td>
#       <td id="T_6ddcb_row1_col7" class="data row1 col7" >2.6280</td>
#     </tr>
#     <tr>
#       <th id="T_6ddcb_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_6ddcb_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_6ddcb_row2_col1" class="data row2 col1" >0.2979</td>
#       <td id="T_6ddcb_row2_col2" class="data row2 col2" >0.1512</td>
#       <td id="T_6ddcb_row2_col3" class="data row2 col3" >0.3887</td>
#       <td id="T_6ddcb_row2_col4" class="data row2 col4" >0.1872</td>
#       <td id="T_6ddcb_row2_col5" class="data row2 col5" >0.2737</td>
#       <td id="T_6ddcb_row2_col6" class="data row2 col6" >0.5859</td>
#       <td id="T_6ddcb_row2_col7" class="data row2 col7" >7.0570</td>
#     </tr>
#     <tr>
#       <th id="T_6ddcb_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_6ddcb_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_6ddcb_row3_col1" class="data row3 col1" >0.3083</td>
#       <td id="T_6ddcb_row3_col2" class="data row3 col2" >0.1540</td>
#       <td id="T_6ddcb_row3_col3" class="data row3 col3" >0.3924</td>
#       <td id="T_6ddcb_row3_col4" class="data row3 col4" >0.1718</td>
#       <td id="T_6ddcb_row3_col5" class="data row3 col5" >0.2774</td>
#       <td id="T_6ddcb_row3_col6" class="data row3 col6" >0.5990</td>
#       <td id="T_6ddcb_row3_col7" class="data row3 col7" >8.2840</td>
#     </tr>
#     <tr>
#       <th id="T_6ddcb_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_6ddcb_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_6ddcb_row4_col1" class="data row4 col1" >0.3064</td>
#       <td id="T_6ddcb_row4_col2" class="data row4 col2" >0.1549</td>
#       <td id="T_6ddcb_row4_col3" class="data row4 col3" >0.3935</td>
#       <td id="T_6ddcb_row4_col4" class="data row4 col4" >0.1671</td>
#       <td id="T_6ddcb_row4_col5" class="data row4 col5" >0.2783</td>
#       <td id="T_6ddcb_row4_col6" class="data row4 col6" >0.5940</td>
#       <td id="T_6ddcb_row4_col7" class="data row4 col7" >1.6180</td>
#     </tr>
#     <tr>
#       <th id="T_6ddcb_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_6ddcb_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_6ddcb_row5_col1" class="data row5 col1" >0.3248</td>
#       <td id="T_6ddcb_row5_col2" class="data row5 col2" >0.1605</td>
#       <td id="T_6ddcb_row5_col3" class="data row5 col3" >
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=6764, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#               subsample_for_bin=200000, subsample_freq=0)

# %%
_ = setup(data=pd.concat([train, pd.DataFrame(target['Other_Faults'])], axis=1), target = 'Other_Faults')
# Out:
# <style type="text/css">
# #T_5628b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5628b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5628b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5628b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5628b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5628b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5628b_row0_col1" class="data row0 col1" >6759</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5628b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5628b_row1_col1" class="data row1 col1" >Other_Faults</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5628b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5628b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5628b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5628b_row3_col1" class="data row3 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5628b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5628b_row4_col1" class="data row4 col1" >(19219, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5628b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5628b_row5_col1" class="data row5 col1" >(13453, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5628b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5628b_row6_col1" class="data row6 col1" >(5766, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5628b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5628b_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5628b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_5628b_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5628b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_5628b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5628b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_5628b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5628b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_5628b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5628b_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_5628b_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5628b_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_5628b_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5628b_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_5628b_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5628b_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_5628b_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5628b_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5628b_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5628b_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5628b_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5628b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5628b_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5628b_row18_col1" class="data row18 col1" >d267</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_23983 th {
#   text-align: left;
# }
# #T_23983_row0_col0, #T_23983_row0_col1, #T_23983_row0_col6, #T_23983_row1_col0, #T_23983_row1_col1, #T_23983_row1_col2, #T_23983_row1_col3, #T_23983_row1_col4, #T_23983_row1_col5, #T_23983_row1_col6, #T_23983_row2_col0, #T_23983_row2_col2, #T_23983_row2_col3, #T_23983_row2_col4, #T_23983_row2_col5, #T_23983_row2_col6, #T_23983_row3_col0, #T_23983_row3_col1, #T_23983_row3_col2, #T_23983_row3_col3, #T_23983_row3_col4, #T_23983_row3_col5, #T_23983_row3_col6, #T_23983_row4_col0, #T_23983_row4_col1, #T_23983_row4_col2, #T_23983_row4_col3, #T_23983_row4_col4, #T_23983_row4_col5, #T_23983_row4_col6, #T_23983_row5_col0, #T_23983_row5_col1, #T_23983_row5_col2, #T_23983_row5_col3, #T_23983_row5_col4, #T_23983_row5_col5, #T_23983_row5_col6, #T_23983_row6_col0, #T_23983_row6_col1, #T_23983_row6_col2, #T_23983_row6_col3, #T_23983_row6_col4, #T_23983_row6_col5, #T_23983_row6_col6, #T_23983_row7_col0, #T_23983_row7_col1, #T_23983_row7_col2, #T_23983_row7_col3, #T_23983_row7_col4, #T_23983_row7_col5, #T_23983_row7_col6, #T_23983_row8_col0, #T_23983_row8_col1, #T_23983_row8_col2, #T_23983_row8_col3, #T_23983_row8_col4, #T_23983_row8_col5, #T_23983_row8_col6, #T_23983_row9_col0, #T_23983_row9_col1, #T_23983_row9_col2, #T_23983_row9_col3, #T_23983_row9_col4, #T_23983_row9_col5, #T_23983_row9_col6, #T_23983_row10_col0, #T_23983_row10_col1, #T_23983_row10_col2, #T_23983_row10_col3, #T_23983_row10_col4, #T_23983_row10_col5, #T_23983_row10_col6, #T_23983_row11_col0, #T_23983_row11_col1, #T_23983_row11_col2, #T_23983_row11_col3, #T_23983_row11_col4, #T_23983_row11_col5, #T_23983_row11_col6, #T_23983_row12_col0, #T_23983_row12_col1, #T_23983_row12_col2, #T_23983_row12_col3, #T_23983_row12_col4, #T_23983_row12_col5, #T_23983_row12_col6, #T_23983_row13_col0, #T_23983_row13_col1, #T_23983_row13_col2, #T_23983_row13_col3, #T_23983_row13_col4, #T_23983_row13_col5, #T_23983_row13_col6, #T_23983_row14_col0, #T_23983_row14_col1, #T_23983_row14_col2, #T_23983_row14_col3, #T_23983_row14_col4, #T_23983_row14_col5, #T_23983_row14_col6, #T_23983_row15_col0, #T_23983_row15_col1, #T_23983_row15_col2, #T_23983_row15_col3, #T_23983_row15_col4, #T_23983_row15_col5, #T_23983_row15_col6, #T_23983_row16_col0, #T_23983_row16_col1, #T_23983_row16_col2, #T_23983_row16_col3, #T_23983_row16_col4, #T_23983_row16_col5, #T_23983_row16_col6, #T_23983_row17_col0, #T_23983_row17_col1, #T_23983_row17_col2, #T_23983_row17_col3, #T_23983_row17_col4, #T_23983_row17_col5, #T_23983_row17_col6, #T_23983_row18_col0, #T_23983_row18_col1, #T_23983_row18_col2, #T_23983_row18_col3, #T_23983_row18_col4, #T_23983_row18_col5, #T_23983_row18_col6, #T_23983_row19_col0, #T_23983_row19_col1, #T_23983_row19_col2, #T_23983_row19_col3, #T_23983_row19_col4, #T_23983_row19_col5 {
#   text-align: left;
# }
# #T_23983_row0_col2, #T_23983_row0_col3, #T_23983_row0_col4, #T_23983_row0_col5, #T_23983_row2_col1, #T_23983_row19_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_23983_row0_col7, #T_23983_row1_col7, #T_23983_row2_col7, #T_23983_row3_col7, #T_23983_row4_col7, #T_23983_row5_col7, #T_23983_row7_col7, #T_23983_row8_col7, #T_23983_row9_col7, #T_23983_row10_col7, #T_23983_row11_col7, #T_23983_row12_col7, #T_23983_row13_col7, #T_23983_row14_col7, #T_23983_row15_col7, #T_23983_row16_col7, #T_23983_row17_col7, #T_23983_row18_col7, #T_23983_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_23983_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_23983">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23983_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_23983_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_23983_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_23983_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_23983_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_23983_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_23983_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_23983_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23983_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_23983_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_23983_row0_col1" class="data row0 col1" >0.4044</td>
#       <td id="T_23983_row0_col2" class="data row0 col2" >0.2027</td>
#       <td id="T_23983_row0_col3" class="data row0 col3" >0.4502</td>
#       <td id="T_23983_row0_col4" class="data row0 col4" >0.0987</td>
#       <td id="T_23983_row0_col5" class="data row0 col5" >0.3166</td>
#       <td id="T_23983_row0_col6" class="data row0 col6" >0.5904</td>
#       <td id="T_23983_row0_col7" class="data row0 col7" >2.6090</td>
#     </tr>
#     <tr>
#       <th id="T_23983_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_23983_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_23983_row1_col1" class="data row1 col1" >0.3992</td>
#       <td id="T_23983_row1_col2" class="data row1 col2" >0.2042</td>
#       <td id="T_23983_row1_col3" class="data row1 col3" >0.4519</td>
#       <td id="T_23983_row1_col4" class="data row1 col4" >0.0919</td>
#       <td id="T_23983_row1_col5" class="data row1 col5" >0.3177</td>
#       <td id="T_23983_row1_col6" class="data row1 col6" >0.5822</td>
#       <td id="T_23983_row1_col7" class="data row1 col7" >0.3390</td>
#     </tr>
#     <tr>
#       <th id="T_23983_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_23983_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_23983_row2_col1" class="data row2 col1" >0.3981</td>
#       <td id="T_23983_row2_col2" class="data row2 col2" >0.2062</td>
#       <td id="T_23983_row2_col3" class="data row2 col3" >0.4540</td>
#       <td id="T_23983_row2_col4" class="data row2 col4" >0.0833</td>
#       <td id="T_23983_row2_col5" class="data row2 col5" >0.3194</td>
#       <td id="T_23983_row2_col6" class="data row2 col6" >0.5798</td>
#       <td id="T_23983_row2_col7" class="data row2 col7" >6.7870</td>
#     </tr>
#     <tr>
#       <th id="T_23983_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_23983_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_23983_row3_col1" class="data row3 col1" >0.4182</td>
#       <td id="T_23983_row3_col2" class="data row3 col2" >0.2071</td>
#       <td id="T_23983_row3_col3" class="data row3 col3" >0.4551</td>
#       <td id="T_23983_row3_col4" class="data row3 col4" >0.0791</td>
#       <td id="T_23983_row3_col5" class="data row3 col5" >0.3216</td>
#       <td id="T_23983_row3_col6" class="data row3 col6" >0.5932</td>
#       <td id="T_23983_row3_col7" class="data row3 col7" >0.1930</td>
#     </tr>
#     <tr>
#       <th id="T_23983_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_23983_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_23983_row4_col1" class="data row4 col1" >0.4073</td>
#       <td id="T_23983_row4_col2" class="data row4 col2" >0.2078</td>
#       <td id="T_23983_row4_col3" class="data row4 col3" >0.4558</td>
#       <td id="T_23983_row4_col4" class="data row4 col4" >0.0760</td>
#       <td id="T_23983_row4_col5" class="data row4 col5" >0.3222</td>
#       <td id="T_23983_row4_col6" class="data row4 col6" >0.5775</td>
#       <td id="T_23983_row4_col7" class="data row4 col7" >9.7220</td>
#     </tr>
#     <tr>
#       <th id="T_23983_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_23983_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_23983_row5_col1" class="data row5 col1" >0.4052</td>
#       <td id="T_23983_row5_col2" class="data row5 col2" >0.2084</td>
#       <td id="T_23983_row5_col3" class="data row5 col3" >
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=6759, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
