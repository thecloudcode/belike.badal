# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
s = pd.read_csv("sample_submission.csv")

# %%
train.shape, test.shape
# Out:
# ((150000, 32), (69129, 31))

# %%
target = train['IsFraud'].copy()
train.drop(columns=['id', 'IsFraud'], inplace=True)
test.drop(columns=['id'], inplace=True)

# %%
target.value_counts()
# Out:
# IsFraud
# 0    149731
# 1       269
# Name: count, dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
# add binary features based on shap dependency plots
def add_binary_flags(df: pd.DataFrame) -> pd.DataFrame:
    df["feat9_feat6_binary"] = ((df["feat9"] > 0) & (df["feat6"] > 1))
    df["feat4_feat13_binary"] = ((df["feat4"] > 0) & (df["feat13"] > 0.5))
    df["Transaction_Amount_feat9_binary"] = ((df["Transaction_Amount"] > 0) & (df["feat13"] > 1.2))
    df["feat18_feat19_binary"] = ((df["feat18"] > 0) & (df["feat19"] <= 0.5) & (df["feat19"] >= -0.5))
    df["feat18_feat20_binary"] = ((df["feat18"] > 0) & (df["feat20"] <= 0.5) & (df["feat20"] >= -0.5))
    return df

# %%
train = add_binary_flags(train)
test = add_binary_flags(test)

# %% [markdown]
# ### PyCarret

# %%
from pycaret.classification import *

# %%
_ = setup(data=pd.concat([train, target], axis=1), target = 'IsFraud', profile = True)
# Out:
# <style type="text/css">
# #T_cb5e4_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cb5e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb5e4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cb5e4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb5e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb5e4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cb5e4_row0_col1" class="data row0 col1" >8304</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb5e4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cb5e4_row1_col1" class="data row1 col1" >IsFraud</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb5e4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cb5e4_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb5e4_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cb5e4_row3_col1" class="data row3 col1" >(150000, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb5e4_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cb5e4_row4_col1" class="data row4 col1" >(150000, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb5e4_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cb5e4_row5_col1" class="data row5 col1" >(105000, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb5e4_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cb5e4_row6_col1" class="data row6 col1" >(45000, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb5e4_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_cb5e4_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cb5e4_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_cb5e4_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cb5e4_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_cb5e4_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cb5e4_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_cb5e4_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cb5e4_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_cb5e4_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cb5e4_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_cb5e4_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cb5e4_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_cb5e4_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cb5e4_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_cb5e4_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cb5e4_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_cb5e4_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cb5e4_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_cb5e4_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cb5e4_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_cb5e4_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cb5e4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cb5e4_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_cb5e4_row18_col1" class="data row18 col1" >9ef3</td>
#     </tr>
#   </tbody>
# </table>
# Loading profile... Please Wait!
# Profiler Failed. No output to show, continue with modeling.
# c:\Users\badal\anaconda3\envs\pycarrot\lib\site-packages\pycaret\internal\metrics.py:51: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
compare_models(sort='AUC')
# Out:
# <style type="text/css">
# #T_300e3 th {
#   text-align: left;
# }
# #T_300e3_row0_col0, #T_300e3_row0_col1, #T_300e3_row0_col4, #T_300e3_row0_col5, #T_300e3_row0_col6, #T_300e3_row0_col7, #T_300e3_row1_col0, #T_300e3_row1_col1, #T_300e3_row1_col2, #T_300e3_row1_col3, #T_300e3_row1_col4, #T_300e3_row1_col5, #T_300e3_row1_col6, #T_300e3_row1_col7, #T_300e3_row2_col0, #T_300e3_row2_col1, #T_300e3_row2_col2, #T_300e3_row2_col3, #T_300e3_row2_col4, #T_300e3_row3_col0, #T_300e3_row3_col1, #T_300e3_row3_col2, #T_300e3_row3_col3, #T_300e3_row3_col5, #T_300e3_row3_col6, #T_300e3_row3_col7, #T_300e3_row4_col0, #T_300e3_row4_col1, #T_300e3_row4_col2, #T_300e3_row4_col3, #T_300e3_row4_col4, #T_300e3_row4_col5, #T_300e3_row4_col6, #T_300e3_row4_col7, #T_300e3_row5_col0, #T_300e3_row5_col1, #T_300e3_row5_col2, #T_300e3_row5_col3, #T_300e3_row5_col4, #T_300e3_row5_col5, #T_300e3_row5_col6, #T_300e3_row5_col7, #T_300e3_row6_col0, #T_300e3_row6_col2, #T_300e3_row6_col3, #T_300e3_row6_col4, #T_300e3_row6_col5, #T_300e3_row6_col6, #T_300e3_row6_col7, #T_300e3_row7_col0, #T_300e3_row7_col2, #T_300e3_row7_col3, #T_300e3_row7_col4, #T_300e3_row7_col5, #T_300e3_row7_col6, #T_300e3_row7_col7, #T_300e3_row8_col0, #T_300e3_row8_col1, #T_300e3_row8_col2, #T_300e3_row8_col3, #T_300e3_row8_col4, #T_300e3_row8_col5, #T_300e3_row8_col6, #T_300e3_row8_col7, #T_300e3_row9_col0, #T_300e3_row9_col1, #T_300e3_row9_col2, #T_300e3_row9_col3, #T_300e3_row9_col4, #T_300e3_row9_col5, #T_300e3_row9_col6, #T_300e3_row9_col7, #T_300e3_row10_col0, #T_300e3_row10_col2, #T_300e3_row10_col3, #T_300e3_row10_col4, #T_300e3_row10_col5, #T_300e3_row10_col6, #T_300e3_row10_col7, #T_300e3_row11_col0, #T_300e3_row11_col2, #T_300e3_row11_col3, #T_300e3_row11_col4, #T_300e3_row11_col5, #T_300e3_row11_col6, #T_300e3_row11_col7, #T_300e3_row12_col0, #T_300e3_row12_col1, #T_300e3_row12_col2, #T_300e3_row12_col3, #T_300e3_row12_col4, #T_300e3_row12_col5, #T_300e3_row12_col6, #T_300e3_row12_col7, #T_300e3_row13_col0, #T_300e3_row13_col2, #T_300e3_row13_col3, #T_300e3_row13_col4, #T_300e3_row13_col5, #T_300e3_row13_col6, #T_300e3_row13_col7 {
#   text-align: left;
# }
# #T_300e3_row0_col2, #T_300e3_row0_col3, #T_300e3_row2_col5, #T_300e3_row2_col6, #T_300e3_row2_col7, #T_300e3_row3_col4, #T_300e3_row6_col1, #T_300e3_row7_col1, #T_300e3_row10_col1, #T_300e3_row11_col1, #T_300e3_row13_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_300e3_row0_col8, #T_300e3_row1_col8, #T_300e3_row2_col8, #T_300e3_row3_col8, #T_300e3_row4_col8, #T_300e3_row5_col8, #T_300e3_row6_col8, #T_300e3_row7_col8, #T_300e3_row8_col8, #T_300e3_row9_col8, #T_300e3_row10_col8, #T_300e3_row11_col8, #T_300e3_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_300e3_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_300e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_300e3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_300e3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_300e3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_300e3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_300e3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_300e3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_300e3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_300e3_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_300e3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_300e3_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_300e3_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_300e3_row0_col1" class="data row0 col1" >0.9657</td>
#       <td id="T_300e3_row0_col2" class="data row0 col2" >0.7767</td>
#       <td id="T_300e3_row0_col3" class="data row0 col3" >0.3243</td>
#       <td id="T_300e3_row0_col4" class="data row0 col4" >0.0174</td>
#       <td id="T_300e3_row0_col5" class="data row0 col5" >0.0329</td>
#       <td id="T_300e3_row0_col6" class="data row0 col6" >0.0296</td>
#       <td id="T_300e3_row0_col7" class="data row0 col7" >0.0684</td>
#       <td id="T_300e3_row0_col8" class="data row0 col8" >0.4650</td>
#     </tr>
#     <tr>
#       <th id="T_300e3_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_300e3_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_300e3_row1_col1" class="data row1 col1" >0.9822</td>
#       <td id="T_300e3_row1_col2" class="data row1 col2" >0.7520</td>
#       <td id="T_300e3_row1_col3" class="data row1 col3" >0.2395</td>
#       <td id="T_300e3_row1_col4" class="data row1 col4" >0.0250</td>
#       <td id="T_300e3_row1_col5" class="data row1 col5" >0.0453</td>
#       <td id="T_300e3_row1_col6" class="data row1 col6" >0.0422</td>
#       <td id="T_300e3_row1_col7" class="data row1 col7" >0.0725</td>
#       <td id="T_300e3_row1_col8" class="data row1 col8" >0.2410</td>
#     </tr>
#     <tr>
#       <th id="T_300e3_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_300e3_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_300e3_row2_col1" class="data row2 col1" >0.9931</td>
#       <td id="T_300e3_row2_col2" class="data row2 col2" >0.7512</td>
#       <td id="T_300e3_row2_col3" class="data row2 col3" >0.1488</td>
#       <td id="T_300e3_row2_col4" class="data row2 col4" >0.0482</td>
#       <td id="T_300e3_row2_col5" class="data row2 col5" >0.0724</td>
#       <td id="T_300e3_row2_col6" class="data row2 col6" >0.0699</td>
#       <td id="T_300e3_row2_col7" class="data row2 col7" >0.0815</td>
#       <td id="T_300e3_row2_col8" class="data row2 col8" >0.2550</td>
#     </tr>
#     <tr>
#       <th id="T_300e3_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_300e3_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_300e3_row3_col1" class="data row3 col1" >0.9980</td>
#       <td id="T_300e3_row3_col2" class="data row3 col2" >0.7483</td>
#       <td id="T_300e3_row3_col3" class="data row3 col3" >0.0319</td>
#       <td id="T_300e3_row3_col4" class="data row3 col4" >0.2150</td>
#       <td id="T_300e3_row3_col5" class="data row3 col5" >0.0530</td>
#       <td id="T_300e3_row3_col6" class="data row3 col6" >0.0525</td>
#       <td id="T_300e3_row3_col7" class="data row3 col7" >0.0775</td>
#       <td id="T_300e3_row3_col8" class="data row3 col8" >17.7520</td>
#     </tr>
#     <tr>
#       <th id="T_300e3_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_300e3_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_300e3_row4_col1" class="data row4 col1" >0.9976</td>
#       <td id="T_300e3_row4_col2" class="data row4 col2" >0.7356</td>
#       <td id="T_300e3_row4_col3" class="data row4 col3" >0.0266</td>
#       <td id="T_300e3_row4_col4" class="data row4 col4" >0.0612</td>
#       <td id="T_300e3_row4_col5" class="data row4 col5" >0.0362</td>
#       <td id="T_300e3_row4_col6" class="data row4 col6" >0.0352</td>
#       <td id="T_300e3_row4_col7" class="data row4 col7" >0.0387</td>
#       <td id="T_300e3_row4_col8" class="data row4 col8" >71.3540</td>
#     </tr>
#     <tr>
#       <th id="T_300e3_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_300e3_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_300e3_row5_col1" class="data row5 col1" >0.9981</td>
#       <td id="T_300e3_row5_col2" class="data row5 col2" >0.7154</td>
#       <td id="T_300e3_row5_col3" class="data row5 col3" >0.0213</td>
#       <td id="T_300e3_row5_col4" class="data row5 col4" >0.1500</td>
#       <td id="T_300e3_row5_col5" class="data row5 col5" >0.0372</td>
#       <td id="T_300e3_row5_col6" class="data row5 col6" >0.0369</td>
#       <td id="T_300e3_row5_col7" class="data row5 col7" >0.0559</td>
#       <td id="T
# c:\Users\badal\anaconda3\envs\pycarrot\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:323: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   master_display_.apply(
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)
