# %%
import pandas as pd
import numpy as np

import mplcyberpunk
import matplotlib.pyplot as plt

from scipy.stats import boxcox

pd.options.display.max_columns
pd.set_option('display.max_rows', 500)

import scipy.stats

plt.style.use("cyberpunk")

from datetime import datetime
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
s = pd.read_csv("sample_submission.csv")

# %%
target = pd.DataFrame(train['Rings'])
train.drop(columns = ['id', 'Rings'], inplace = True)
test.drop(columns=['id'], inplace= True)

train.shape, test.shape
# Out:
# ((90615, 8), (60411, 8))

# %%
data = pd.concat([train, test], axis = 0).reset_index(drop=True)
data.shape
# Out:
# (151026, 8)

# %%
data.rename(columns={'Whole weight.1': 'Shucked weight'}, inplace=True)
data.rename(columns={'Whole weight.2': 'Viscera weight'}, inplace=True)
data.rename(columns={'Whole weight': 'Whole weight'}, inplace=True)
data.rename(columns={'Shell weight': 'Shell weight'}, inplace=True)

# %%
data['Sex'] = data['Sex'].astype('category').cat.codes

# %%
def boxcox_transform(series):
    series = series + 1e-10
    transformed, _ = boxcox(series)
    return transformed

# %%
for i in data.columns:
    if abs(scipy.stats.skew(data[i])) >= 0.5:
        if abs(scipy.stats.skew(np.log1p(data[i])) < 0.5):
            data[i] = np.log1p(data[i])

# %%
scipy.stats.skew(data)
# Out:
# array([-0.09379876, -0.93272439, -0.86310085,  0.40859532,  0.43184444,
#         0.21590715,  0.47648355,  0.4748712 ])

# %%
data.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight'],
#       dtype='object')

# %%
scaler = StandardScaler()
scaler.fit(data)

data2 = pd.DataFrame(scaler.transform(data), index=data.index, columns = data.columns)

# %%
data2
# Out:
#              Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0      -1.325117  0.304335  0.312275  0.378761     -0.039214        0.013068
# 1      -1.325117  0.928483  0.883855  0.247439      0.744160        0.635236
# 2      -0.066092 -3.290290 -3.210437 -2.904273     -1.679164       -1.850227
# 3       1.192934  0.659275  0.743147  0.378761      0.273261        0.245619
# 4      -0.066092  0.344278  0.263566 -0.146525     -0.016270        0.216378
# ...          ...       ...       ...       ...           ...             ...
# 151021 -0.066092 -1.455069 -1.447767 -1.328417     -1.337189       -1.412510
# 151022 -1.325117  0.102667  0.116406  0.247439      0.120301        0.308540
# 151023 -0.066092  0.620335  0.409185  0.510082      0.726678        0.330183
# 151024 -1.325117  1.154671  1.206739  1.429331      1.538459        1.208639
# 151025 -1.325117 -0.695050 -0.591713 -0.409168     -0.818218       -0.937537
#
#         Viscera weight  Shell weight
# 0            -0.227315      0.107737
# 1             1.061947      0.722876
# 2            -1.650462     -1.699234
# 3             0.357811      0.184629
# 4            -0.093430     -0.219056
# ...                ...           ...
# 151021       -1.417403     -1.353218
# 151022       -0.024008     -0.161386
# 151023        0.303266      0.299968
# 151024        1.865256      1.607138
# 151025       -0.777731     -1.041804
#
# [151026 rows x 8 columns]

# %%
target['Rings'] = np.log1p(target['Rings'])
scipy.stats.skew(target)
# Out:
# array([-0.01086627])

# %%
train2 = data.loc[:train.index.max(), :].copy()
test2 = data.loc[train.index.max()+1:,:].reset_index(drop = True).copy()

# %%
from pycaret.regression import *

# %%
_ = setup(data=pd.concat([train2, target], axis=1), target = 'Rings')
# Out:
# <style type="text/css">
# #T_e7bbb_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e7bbb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7bbb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e7bbb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7bbb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7bbb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e7bbb_row0_col1" class="data row0 col1" >7042</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7bbb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e7bbb_row1_col1" class="data row1 col1" >Rings</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7bbb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e7bbb_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7bbb_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e7bbb_row3_col1" class="data row3 col1" >(90615, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e7bbb_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e7bbb_row4_col1" class="data row4 col1" >(90615, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e7bbb_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e7bbb_row5_col1" class="data row5 col1" >(63430, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e7bbb_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e7bbb_row6_col1" class="data row6 col1" >(27185, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e7bbb_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e7bbb_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e7bbb_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e7bbb_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e7bbb_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e7bbb_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e7bbb_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e7bbb_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e7bbb_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e7bbb_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e7bbb_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e7bbb_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e7bbb_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e7bbb_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e7bbb_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e7bbb_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e7bbb_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e7bbb_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e7bbb_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e7bbb_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e7bbb_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e7bbb_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e7bbb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e7bbb_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e7bbb_row18_col1" class="data row18 col1" >68e3</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = compare_models(sort='RMSLE')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           18:55:53
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_a7d74 th {
#   text-align: left;
# }
# #T_a7d74_row0_col0, #T_a7d74_row1_col0, #T_a7d74_row1_col1, #T_a7d74_row1_col2, #T_a7d74_row1_col3, #T_a7d74_row1_col4, #T_a7d74_row1_col5, #T_a7d74_row1_col6, #T_a7d74_row2_col0, #T_a7d74_row2_col1, #T_a7d74_row2_col2, #T_a7d74_row2_col3, #T_a7d74_row2_col4, #T_a7d74_row2_col5, #T_a7d74_row2_col6, #T_a7d74_row3_col0, #T_a7d74_row3_col1, #T_a7d74_row3_col2, #T_a7d74_row3_col3, #T_a7d74_row3_col4, #T_a7d74_row3_col5, #T_a7d74_row3_col6, #T_a7d74_row4_col0, #T_a7d74_row4_col1, #T_a7d74_row4_col2, #T_a7d74_row4_col3, #T_a7d74_row4_col4, #T_a7d74_row4_col5, #T_a7d74_row4_col6, #T_a7d74_row5_col0, #T_a7d74_row5_col1, #T_a7d74_row5_col2, #T_a7d74_row5_col3, #T_a7d74_row5_col4, #T_a7d74_row5_col5, #T_a7d74_row5_col6, #T_a7d74_row6_col0, #T_a7d74_row6_col1, #T_a7d74_row6_col2, #T_a7d74_row6_col3, #T_a7d74_row6_col4, #T_a7d74_row6_col5, #T_a7d74_row6_col6, #T_a7d74_row7_col0, #T_a7d74_row7_col1, #T_a7d74_row7_col2, #T_a7d74_row7_col3, #T_a7d74_row7_col4, #T_a7d74_row7_col5, #T_a7d74_row7_col6, #T_a7d74_row8_col0, #T_a7d74_row8_col1, #T_a7d74_row8_col2, #T_a7d74_row8_col3, #T_a7d74_row8_col4, #T_a7d74_row8_col5, #T_a7d74_row8_col6, #T_a7d74_row9_col0, #T_a7d74_row9_col1, #T_a7d74_row9_col2, #T_a7d74_row9_col3, #T_a7d74_row9_col4, #T_a7d74_row9_col5, #T_a7d74_row9_col6, #T_a7d74_row10_col0, #T_
row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_a7d74_row0_col1" class="data row0 col1" >0.1084</td>
#       <td id="T_a7d74_row0_col2" class="data row0 col2" >0.0221</td>
#       <td id="T_a7d74_row0_col3" class="data row0 col3" >0.1485</td>
#       <td id="T_a7d74_row0_col4" class="data row0 col4" >0.7265</td>
#       <td id="T_a7d74_row0_col5" class="data row0 col5" >0.0446</td>
#       <td id="T_a7d74_row0_col6" class="data row0 col6" >0.0468</td>
#       <td id="T_a7d74_row0_col7" class="data row0 col7" >6.3850</td>
#     </tr>
#     <tr>
#       <th id="T_a7d74_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_a7d74_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a7d74_row1_col1" class="data row1 col1" >0.1089</td>
#       <td id="T_a7d74_row1_col2" class="data row1 col2" >0.0223</td>
#       <td id="T_a7d74_row1_col3" class="data row1 col3" >0.1492</td>
#       <td id="T_a7d74_row1_col4" class="data row1 col4" >0.7239</td>
#       <td id="T_a7d74_row1_col5" class="data row1 col5" >0.0448</td>
#       <td id="T_a7d74_row1_col6" class="data row1 col6" >0.0470</td>
#       <td id="T_a7d74_row1_col7" class="data row1 col7" >0.4860</td>
#     </tr>
#     <tr>
#       <th id="T_a7d74_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_a7d74_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_a7d74_row2_col1" class="data row2 col1" >0.1091</td>
#       <td id="T_a7d74_row2_col2" class="data row2 col2" >0.0224</td>
#       <td id="T_a7d74_row2_col3" class="data row2 col3" >0.1496</td>
#       <td id="T_a7d74_row2_col4" class="data row2 col4" >0.7224</td>
#       <td id="T_a7d74_row2_col5" class="data row2 col5" >0.0449</td>
#       <td id="T_a7d74_row2_col6" class="data row2 col6" >0.0471</td>
#       <td id="T_a7d74_row2_col7" class="data row2 col7" >1.4620</td>
#     </tr>
#     <tr>
#       <th id="T_a7d74_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_a7d74_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a7d74_row3_col1" class="data row3 col1" >0.1114</td>
#       <td id="T_a7d74_row3_col2" class="data row3 col2" >0.0231</td>
#       <td id="T_a7d74_row3_col3" class="data row3 col3" >0.1521</td>
#       <td id="T_a7d74_row3_col4" class="data row3 col4" >0.7132</td>
#       <td id="T_a7d74_row3_col5" class="data row3 col5" >0.0455</td>
#       <td id="T_a7d74_row3_col6" class="data row3 col6" >0.0480</td>
#       <td id="T_a7d74_row3_col7" class="data row3 col7" >2.5100</td>
#     </tr>
#     <tr>
#       <th id="T_a7d74_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_a7d74_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_a7d74_row4_col1" class="data row4 col1" >0.1118</td>
#       <td id="T_a7d74_row4_col2" class="data row4 col2" >0.0233</td>
#       <td id="T_a7d74_row4_col3" class="data row4 col3" >0.1526</td>
#       <td id="T_a7d74_row4_col4" class="data row4 col4" >0.7115</td>
#       <td id="T_a7d74_row4_col5" class="data row4 col5" >0.0458</td>
#       <td id="T_a7d74_row4_col6" class="data row4 col6" >0.0484</td>
#       <td id="T_a7d74_row4_col7" class="data row4 col7" >13.0140</td>
#     </tr>
#     <tr>
#       <th id="T_a7d74_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_a7d74_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_a7d74_row5_col1" class="data row5 col1" >0.1125</td>
#       <td id="T_a7d74_row5_col2" class="data row5 col2" >0.0235</td>
#       <td id="T_a7d74_row5_col3" class="data

# %%
p = np.expm1(model.predict(test2))

# %%
s['Rings'] = p

# %%
s.to_csv("Submission1.csv", header=True, index = False)
